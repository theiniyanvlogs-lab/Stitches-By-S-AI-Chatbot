# %%
# ==========================================================
# STEP 1 : Clone GitHub Repository
# ==========================================================

# !git clone https://github.com/theiniyanvlogs-lab/Stitches-By-S-AI-Chatbot.git

# %cd Stitches-By-S-AI-Chatbot

# !pwd
# !ls
# Out:
# fatal: destination path 'Stitches-By-S-AI-Chatbot' already exists and is not an empty directory.
# /content/Stitches-By-S-AI-Chatbot
# /content/Stitches-By-S-AI-Chatbot
# agents	    data     models	  README.md		    test_groq.py
# app_old.py  graph    prompts	  requirements.txt	    utils
# app.py	    LICENSE  __pycache__  scripts		    vector_db
# config.py   memory   rag	  Stitches-By-S-AI-Chatbot

# %%
# ==========================================================
# STEP 2 : Install Packages
# ==========================================================

# !pip install -U pip

# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.2)
# Requirement already satisfied: langchain>=0.3.27 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.3.13)
# Requirement already satisfied: langchain-core>=0.3.74 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.4.9)
# Requirement already satisfied: langchain-community>=0.3.27 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: langchain-text-splitters>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.1.2)
# Requirement already satisfied: langchain-huggingface>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.2.2)
# Requirement already satisfied: langchain-groq>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (1.1.3)
# Requirement already satisfied: langgraph>=0.6.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (1.2.9)
# Requirement already satisfied: langsmith>=0.4.16 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.10.2)
# Requirement already satisfied: groq>=0.31.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.37.1)
# Requirement already satisfied: sentence-transformers>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (5.6.0)
# Requirement already satisfied: transformers>=4.55.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (5.13.1)
# Requirement already satisfied: torch>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (2.11.0+cpu)
# Requirement already satisfied: faiss-cpu>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (1.14.3)
# Requirement already satisfied: pypdf>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (6.14.2)
# Requirement already satisfied: gradio>=5.42.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (5.50.0)
# Requirement already satisfied: python-dotenv>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 29)) (1.2.2)
# Requirement already satisfied: pydantic>=2.11.7 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 32)) (2.11.10)
# Requirement already satisfied: numpy>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 35)) (2.5.1)
# Requirement already satisfied: pandas>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 36)) (2.3.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.74->-r requirements.txt (line 3)) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.74->-r requirements.txt (line 3)) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.74->-r requirements.txt (line 3)) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.74->-r requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.74->-r requirements.txt (line 3)) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.74->-r requirements.txt (line 3)) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.74->-r requirements.txt (line 3)) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph>=0.6.6->-r requirements.txt (line 8)) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph>=0.6.6->-r requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph>=0.6.6->-r requirements.txt (line 8)) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph>=0.6.6->-r requirements.txt (line 8)) (3.8.1)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.4.16->-r requirements.txt (line 9)) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.4.16->-r requirements.txt (line 9)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.4.16->-r requirements.txt (line 9)) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.4.16->-r requirements.txt (line 9)) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.4.16->-r requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.4.16->-r requirements.txt (line 9)) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.4.16->-r requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.4.16->-r requirements.txt (line 9)) (15.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.4.16->-r requirements.txt (line 9)) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.7->-r requirements.txt (line 32)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.7->-r requirements.txt (line 32)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.7->-r requirements.txt (line 32)) (0.4.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.4.16->-r requirements.txt (line 9)) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.4.16->-r requirements.txt (line 9)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.4.16->-r requirements.txt (line 9)) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.4.16->-r requirements.txt (line 9)) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.3.74->-r requirements.txt (line 3)) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph>=0.6.6->-r requirements.txt (line 8)) (1.12.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community>=0.3.27->-r requirements.txt (line 4)) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community>=0.3.27->-r requirements.txt (line 4)) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community>=0.3.27->-r requirements.txt (line 4)) (1.0.8)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community>=0.3.27->-r requirements.txt (line 4)) (2.14.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community>=0.3.27->-r requirements.txt (line 4)) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 4)) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 4)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 4)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 4)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 4)) (1.24.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith>=0.4.16->-r requirements.txt (line 9)) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith>=0.4.16->-r requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community>=0.3.27->-r requirements.txt (line 4)) (3.5.3)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in /usr/local/lib/python3.12/dist-packages (from langchain-huggingface>=0.3.1->-r requirements.txt (line 6)) (1.23.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from langchain-huggingface>=0.3.1->-r requirements.txt (line 6)) (0.22.2)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface>=0.3.1->-r requirements.txt (line 6)) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface>=0.3.1->-r requirements.txt (line 6)) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface>=0.3.1->-r requirements.txt (line 6)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface>=0.3.1->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface>=0.3.1->-r requirements.txt (line 6)) (4.67.3)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=5.1.0->-r requirements.txt (line 15)) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=5.1.0->-r requirements.txt (line 15)) (1.16.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.55.0->-r requirements.txt (line 16)) (2025.11.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers>=4.55.0->-r requirements.txt (line 16)) (0.26.8)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.55.0->-r requirements.txt (line 16)) (0.8.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->-r requirements.txt (line 17)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->-r requirements.txt (line 17)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->-r requirements.txt (line 17)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->-r requirements.txt (line 17)) (3.1.6)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (24.1.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (0.139.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (0.1.2)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (3.0.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (11.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (0.0.32)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (0.16.1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (0.13.3)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.42.0->-r requirements.txt (line 26)) (0.51.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.1->-r requirements.txt (line 36)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.1->-r requirements.txt (line 36)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.1->-r requirements.txt (line 36)) (2026.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio>=5.42.0->-r requirements.txt (line 26)) (0.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.55.0->-r requirements.txt (line 16)) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.55.0->-r requirements.txt (line 16)) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.3.1->-r requirements.txt (line 36)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=4.55.0->-r requirements.txt (line 16)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=4.55.0->-r requirements.txt (line 16)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers>=4.55.0->-r requirements.txt (line 16)) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers>=5.1.0->-r requirements.txt (line 15)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers>=5.1.0->-r requirements.txt (line 15)) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.8.0->-r requirements.txt (line 17)) (1.3.0)

# %%
from google.colab import userdata
import os

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY_3")

# %%
import gradio as gr

print(gr.__version__)
# Out:
# 5.50.0

# %%
# %cd /content/Stitches-By-S-AI-Chatbot

import app
# Out:
# /content/Stitches-By-S-AI-Chatbot
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Loading vector store: /content/Stitches-By-S-AI-Chatbot/vector_db/fabric
# Loading vector store: /content/Stitches-By-S-AI-Chatbot/vector_db/tailoring
# Loading vector store: /content/Stitches-By-S-AI-Chatbot/vector_db/business
# Loading vector store: /content/Stitches-By-S-AI-Chatbot/vector_db/fabric
# Loading vector store: /content/Stitches-By-S-AI-Chatbot/vector_db/tailoring
# Loading vector store: /content/Stitches-By-S-AI-Chatbot/vector_db/business
# Loading vector store: /content/Stitches-By-S-AI-Chatbot/vector_db/fabric
# Loading vector store: /content/Stitches-By-S-AI-Chatbot/vector_db/tailoring
# Loading vector store: /content/Stitches-By-S-AI-Chatbot/vector_db/business

# %%
app.demo.launch(
    share=True,
    debug=True,
    show_error=True
)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://2892ac50c358e24416.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2892ac50c358e24416.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
